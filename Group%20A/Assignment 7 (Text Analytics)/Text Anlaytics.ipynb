# %%
# %pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\tejas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (3.9.4)
# Requirement already satisfied: click in c:\users\tejas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nltk) (8.3.1)
# Requirement already satisfied: joblib in c:\users\tejas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\tejas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nltk) (2026.2.28)
# Requirement already satisfied: tqdm in c:\users\tejas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nltk) (4.67.3)
# Requirement already satisfied: colorama in c:\users\tejas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: C:\Users\Tejas\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import nltk
nltk.download('punkt', download_dir='C:/nltk_data')
nltk.download('punkt_tab', download_dir='C:/nltk_data')
# Out:
# [nltk_data] Downloading package punkt to C:/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to C:/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
import nltk
from nltk.tokenize import word_tokenize
text = "Welcome to the Python Programming at Indeed Insprining Infotech"
print(word_tokenize(text))
# Out:
# ['Welcome', 'to', 'the', 'Python', 'Programming', 'at', 'Indeed', 'Insprining', 'Infotech']

# %%
from nltk.tokenize import sent_tokenize

text = "Hello Everyone. Welcome to the Python Programming"
print(sent_tokenize(text))
# Out:
# ['Hello Everyone.', 'Welcome to the Python Programming']

# %%
from nltk.tokenize import sent_tokenize

text = "Hello Everyone. Welcome to the Python Programming"
print(sent_tokenize(text))
# Out:
# ['Hello Everyone.', 'Welcome to the Python Programming']

# %%
from nltk.stem import PorterStemmer
# words = ['Wait','Waiting','Waited','Waits']
words = ['clean','cleaning','cleans','cleaned']
ps = PorterStemmer()
for w in words:
    words=ps.stem(w)
    print(words)
# Out:
# clean
# clean
# clean
# clean

# %%
import nltk
from nltk.stem.porter import PorterStemmer

porter_stemmer = PorterStemmer()
text  = "studies studying floors cry"
tokenization = nltk.word_tokenize(text)
for w in tokenization:
    print('Stemming for ', w,'is',porter_stemmer.stem(w))
# Out:
# Stemming for  studies is studi
# Stemming for  studying is studi
# Stemming for  floors is floor
# Stemming for  cry is cri

# %%
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Tejas\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Tejas\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
import nltk
from nltk.stem import WordNetLemmatizer
Wordnet_lemmatizer = WordNetLemmatizer()
text  = "studies study floors cry"
tokenization = nltk.word_tokenize(text)
for w in tokenization:
    print('Lemma for ', w,'is',Wordnet_lemmatizer.lemmatize(w))
# Out:
# Lemma for  studies is study
# Lemma for  study is study
# Lemma for  floors is floor
# Lemma for  cry is cry

# %%
import nltk
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

text = "studies study floors cry"
tokens = nltk.word_tokenize(text)

for w in tokens:
    print('Lemma for', w, 'is', lemmatizer.lemmatize(w))
# Out:
# Lemma for studies is study
# Lemma for study is study
# Lemma for floors is floor
# Lemma for cry is cry

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Tejas\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords

data = 'AI was introduced in the year 1956 but it gained popularity recently.'
stopwords = set(stopwords.words('english'))
words = word_tokenize(data)
wordsFiltered = []

for w in words:
    if w not in stopwords:
        wordsFiltered.append(w)
        
print(wordsFiltered)
# Out:
# ['AI', 'introduced', 'year', '1956', 'gained', 'popularity', 'recently', '.']

# %%
print(len(stopwords))
print(stopwords)
# Out:
# 198
# {'that', "you're", 'the', 'into', 'hers', 'under', 'during', 'below', 'all', 'have', 'wasn', "it'll", 'were', 'o', "it'd", 'ain', 'yours', "i've", "hasn't", 'be', "you've", 'what', 'off', "she's", 'with', 'in', 'shan', 'it', "they've", 'until', "you'd", 'me', 're', 'themselves', 'because', 'not', 'my', 'any', "isn't", 'an', 'we', 'over', 'own', 'very', 'been', 'them', 'only', "i'll", "that'll", "shan't", 'are', 'aren', "shouldn't", "it's", "couldn't", "aren't", 'then', 'and', "i'm", 'couldn', "don't", 'mightn', "they'll", 'him', 'if', 'most', 'at', 'mustn', 'up', "doesn't", 'i', 'yourselves', 'theirs', 'their', 's', "wouldn't", 'between', "should've", 'for', "mightn't", 'both', "you'll", 'll', 'of', 'is', 'same', 'other', "haven't", 'just', 'now', 'should', 'against', 'again', 'weren', 'as', 'wouldn', 'will', 'whom', 'which', 'here', 'isn', 'you', "won't", "didn't", 'her', "she'd", 'while', "mustn't", 'hadn', 'too', 'won', 'didn', "needn't", 'himself', 't', 'yourself', 'did', 'being', 'she', "he'd", 'they', 'haven', 'by', 'his', 'herself', 'had', 'about', 'has', 'don', 'more', 'such', 'shouldn', 'doesn', "she'll", "they're", 'was', 'further', 'so', 'than', 'there', 'who', 'a', 'before', 'can', 'itself', 'how', 'myself', 'needn', 'nor', 'some', 'above', 'where', "he'll", 'm', 'does', 'd', "weren't", "he's", 'to', 'do', 've', 'he', 'why', 'doing', 'few', 'hasn', 'on', 'these', 'each', 'out', "we'll", 'ma', 'ourselves', "hadn't", 'your', 'or', 'ours', "we've", 'once', "i'd", 'those', 'when', 'having', "we're", 'after', 'no', 'our', 'down', 'y', 'through', "wasn't", 'this', 'from', 'its', 'but', "they'd", 'am', "we'd"}

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk import pos_tag

# %%
document = "This is an example document that we will use to demonstrate document preprocessing."

# %%
tokens = word_tokenize(document)

# %%
tokens
# Out:
# ['This',
#  'is',
#  'an',
#  'example',
#  'document',
#  'that',
#  'we',
#  'will',
#  'use',
#  'to',
#  'demonstrate',
#  'document',
#  'preprocessing',
#  '.']

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Tejas\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
pos_tags = pos_tag(tokens)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 pos_tags = pos_tag(tokens)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\nltk\tag\__init__.py:168, in pos_tag(tokens, tagset, lang)
#     143 def pos_tag(tokens, tagset=None, lang="eng"):
#     144     """
#     145     Use NLTK's currently recommended part of speech tagger to
#     146     tag the given list of tokens.
#    (...)    166     :rtype: list(tuple(str, str))
#     167     """
# --> 168     tagger = _get_tagger(lang)
#     169     return _pos_tag(tokens, tagset, tagger, lang)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\nltk\tag\__init__.py:110, in _get_tagger(lang)
#     108     tagger = PerceptronTagger(lang=lang)
#     109 else:
# --> 110     tagger = PerceptronTagger()
#     111 return tagger
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\nltk\tag\perceptron.py:183, in PerceptronTagger.__init__(self, load, lang, loc)
#     179 self.save_dir = path_join(
#     180     self.TRAINED_TAGGER_PATH, f"{self.TAGGER_NAME}_{self.lang}"
#     181 )
#     182 if load:
# --> 183     self.load_from_json(lang, loc)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\nltk\tag\perceptron.py:279, in PerceptronTagger.load_from_json(self, lang, loc)
#     275 def load_from_json(self, lang="eng", loc=None):
#     276     # Automatically find path to the tagger if location is not specified.
#     277     # loc can refer to zip or real FS
#     278     if loc is None:
# --> 279         loc = find(f"taggers/averaged_perceptron_tagger_{lang}/")
#     280     elif isinstance(loc, str):
#     281         # Backward compatible:
#     282         # - absolute paths are explicit filesystem locations
#     283         # - relative strings are treated as NLTK resource names and resolved via find()
#     284         if os.path.isabs(loc):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\nltk\data.py:738, in find(resource_name, paths)
#     736 sep = "*" * 70
#     737 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 738 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource 'averaged_perceptron_tagger_eng' not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('averaged_perceptron_tagger_eng')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load 'taggers/averaged_perceptron_tagger_eng/'
#
#   Searched in:
#     - 'C:\\Users\\Tejas/nltk_data'
#     - 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\\nltk_data'
#     - 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\\share\\nltk_data'
#     - 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\\lib\\nltk_data'
#     - 'C:\\Users\\Tejas\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************

# %%
pos_tags

# %%
stop_words = set(stopwords.words('english'))
filtered_tokens = [word for word in tokens if not word.lower() in stop_words]

# %%
ps = PorterStemmer()
stemmed_tokens = [ps.stem(word) for word in filtered_tokens]

# %%
wnl = WordNetLemmatizer()
lemmatized_tokens = [wnl.lemmatize(word) for word in filtered_tokens]

# %%
print("Tokens: ", tokens)
print("POS tags: ", pos_tags)
print("Filtered tokens: ", filtered_tokens)
print("Stemmed tokens: ", stemmed_tokens)
print("Lemmatized tokens: ", lemmatized_tokens)
# Out:
# Tokens:  ['This', 'is', 'an', 'example', 'document', 'that', 'we', 'will', 'use', 'to', 'demonstrate', 'document', 'preprocessing', '.']
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 2
#       1 print("Tokens: ", tokens)
# ----> 2 print("POS tags: ", pos_tags)
#       3 print("Filtered tokens: ", filtered_tokens)
#       4 print("Stemmed tokens: ", stemmed_tokens)
#
# NameError: name 'pos_tags' is not defined

# %%
import math
from collections import Counter

# %%
corpus = [
    'The quick brown fox jumps over the lazy dog',
    'The brown fox is quick',
    'The lazy dog is sleeping'
]

# %%
tokenized_docs = [doc.lower().split() for doc in corpus]

# %%
tf_docs = [Counter(tokens) for tokens in tokenized_docs]

# %%
n_docs = len(corpus)
idf = {}
for tokens in tokenized_docs:
    for token in set(tokens):
        idf[token] = idf.get(token, 0) + 1
for token in idf:
    idf[token] = math.log(n_docs / idf[token])

# %%
tfidf_docs = []
for tf_doc in tf_docs:
    tfidf_doc = {}
    for token, freq in tf_doc.items():
        tfidf_doc[token] = freq * idf[token]
    tfidf_docs.append(tfidf_doc)

# %%
for i, tfidf_doc in enumerate(tfidf_docs):
    print(f"Document {i+1}: {tfidf_doc}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 for i, tfidf_doc in enumerate(tfidf_docs):
#       2     print(f"Document {i+1}: {tfidf_doc}")
#
# NameError: name 'tfidf_docs' is not defined
